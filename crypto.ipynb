# %%
import json
import urllib
import pandas as pd
import numpy as np
import requests
import json
import re
import matplotlib.pyplot as plt

# %%
av_key='4FE1OVK5BRL4VSMY'
url = f'https://www.alphavantage.co/query?function=CRYPTO_INTRADAY&symbol=ETH&market=USD&interval=5min&apikey={av_key}'
r = requests.get(url)
data = r.json()

print(data)
# Out:
# {'Meta Data': {'1. Information': 'Crypto Intraday (5min) Time Series', '2. Digital Currency Code': 'ETH', '3. Digital Currency Name': 'Ethereum', '4. Market Code': 'USD', '5. Market Name': 'United States Dollar', '6. Last Refreshed': '2021-12-29 02:35:00', '7. Interval': '5min', '8. Output Size': 'Compact', '9. Time Zone': 'UTC'}, 'Time Series Crypto (5min)': {'2021-12-29 02:35:00': {'1. open': '3816.36000', '2. high': '3817.54000', '3. low': '3808.05000', '4. close': '3809.43000', '5. volume': 634}, '2021-12-29 02:30:00': {'1. open': '3812.10000', '2. high': '3816.38000', '3. low': '3810.07000', '4. close': '3816.36000', '5. volume': 351}, '2021-12-29 02:25:00': {'1. open': '3815.78000', '2. high': '3816.39000', '3. low': '3811.48000', '4. close': '3812.11000', '5. volume': 423}, '2021-12-29 02:20:00': {'1. open': '3814.56000', '2. high': '3817.43000', '3. low': '3808.19000', '4. close': '3815.78000', '5. volume': 592}, '2021-12-29 02:15:00': {'1. open': '3813.04000', '2. high': '3818.11000', '3. low': '3813.03000', '4. close': '3814.56000', '5. volume': 743}, '2021-12-29 02:10:00': {'1. open': '3813.51000', '2. high': '3816.00000', '3. low': '3811.47000', '4. close': '3813.03000', '5. volume': 1754}, '2021-12-29 02:05:00': {'1. open': '3808.05000', '2. high': '3813.55000', '3. low': '3803.18000', '4. close': '3813.51000', '5. volume': 471}, '2021-12-29 02:00:00': {'1. open': '3801.13000', '2. high': '3809.00000', '3. low': '3798.20000', '4. close': '3808.05000', '5. volume': 449}, '2021-12-29 01:55:00': {'1. open': '3810.34000', '2. high': '3810.77000', '3. low': '3798.35000', '4. close': '3801.37000', '5. volume': 472}, '2021-12-29 01:50:00': {'1. open': '3808.18000', '2. high': '3810.77000', '3. low': '3806.41000', '4. close': '3810.34000', '5. volume': 548}, '2021-12-29 01:45:00': {'1. open': '3805.65000', '2. high': '3809.09000', '3. low': '3802.25000', '4. close': '3808.17000', '5. volume': 1021}, '2021-12-29 01:40:00': {'1. open': '3799.85000', '2. high': '3807.89000', '3. low': '3799.43000', '4. close': '3805.65000', '5. volume': 940}, '2021-12-29 01:35:00': {'1. open': '3801.67000', '2. high': '3806.55000', '3. low': '3797.13000', '4. close': '3800.15000', '5. volume': 462}, '2021-12-29 01:30:00': {'1. open': '3810.00000', '2. high': '3810.01000', '3. low': '3795.83000', '4. close': '3801.67000', '5. volume': 1343}, '2021-12-29 01:25:00': {'1. open': '3821.95000', '2. high': '3822.07000', '3. low': '3809.98000', '4. close': '3810.00000', '5. volume': 579}, '2021-12-29 01:20:00': {'1. open': '3821.26000', '2. high': '3826.24000', '3. low': '3821.26000', '4. close': '3821.95000', '5. volume': 352}, '2021-12-29 01:15:00': {'1. open': '3826.01000', '2. high': '3826.01000', '3. low': '3817.32000', '4. close': '3821.53000', '5. volume': 613}, '2021-12-29 01:10:00': {'1. open': '3823.30000', '2. high': '3826.07000', '3. low': '3819.00000', '4. close': '3826.00000', '5. volume': 848}, '2021-12-29 01:05:00': {'1. open': '3816.91000', '2. high': '3826.85000', '3. low': '3816.91000', '4. close': '3823.30000', '5. volume': 803}, '2021-12-29 01:00:00': {'1. open': '3818.06000', '2. high': '3820.41000', '3. low': '3811.57000', '4. close': '3816.91000', '5. volume': 1004}, '2021-12-29 00:55:00': {'1. open': '3815.03000', '2. high': '3820.00000', '3. low': '3813.75000', '4. close': '3818.07000', '5. volume': 671}, '2021-12-29 00:50:00': {'1. open': '3814.20000', '2. high': '3816.54000', '3. low': '3809.70000', '4. close': '3815.04000', '5. volume': 491}, '2021-12-29 00:45:00': {'1. open': '3800.29000', '2. high': '3816.39000', '3. low': '3799.36000', '4. close': '3814.19000', '5. volume': 1036}, '2021-12-29 00:40:00': {'1. open': '3795.63000', '2. high': '3800.83000', '3. low': '3792.04000', '4. close': '3800.29000', '5. volume': 656}, '2021-12-29 00:35:00': {'1. open': '3802.62000', '2. high': '3804.90000', '3. low': '3792.76000', '4. close': '3795.64000', '5. volume': 889}, '2021-12-29 00:30:00': {'1. open': '3809.18000', '2. high ...

# %%
data.keys()
# Out:
# dict_keys(['Meta Data', 'Time Series Crypto (5min)'])

# %%
data['Meta Data']
# Out:
# {'1. Information': 'Crypto Intraday (5min) Time Series',
#  '2. Digital Currency Code': 'ETH',
#  '3. Digital Currency Name': 'Ethereum',
#  '4. Market Code': 'USD',
#  '5. Market Name': 'United States Dollar',
#  '6. Last Refreshed': '2021-12-29 02:35:00',
#  '7. Interval': '5min',
#  '8. Output Size': 'Compact',
#  '9. Time Zone': 'UTC'}

# %%
data['Time Series Crypto (5min)']
# Out:
# {'2021-12-29 02:35:00': {'1. open': '3816.36000',
#   '2. high': '3817.54000',
#   '3. low': '3808.05000',
#   '4. close': '3809.43000',
#   '5. volume': 634},
#  '2021-12-29 02:30:00': {'1. open': '3812.10000',
#   '2. high': '3816.38000',
#   '3. low': '3810.07000',
#   '4. close': '3816.36000',
#   '5. volume': 351},
#  '2021-12-29 02:25:00': {'1. open': '3815.78000',
#   '2. high': '3816.39000',
#   '3. low': '3811.48000',
#   '4. close': '3812.11000',
#   '5. volume': 423},
#  '2021-12-29 02:20:00': {'1. open': '3814.56000',
#   '2. high': '3817.43000',
#   '3. low': '3808.19000',
#   '4. close': '3815.78000',
#   '5. volume': 592},
#  '2021-12-29 02:15:00': {'1. open': '3813.04000',
#   '2. high': '3818.11000',
#   '3. low': '3813.03000',
#   '4. close': '3814.56000',
#   '5. volume': 743},
#  '2021-12-29 02:10:00': {'1. open': '3813.51000',
#   '2. high': '3816.00000',
#   '3. low': '3811.47000',
#   '4. close': '3813.03000',
#   '5. volume': 1754},
#  '2021-12-29 02:05:00': {'1. open': '3808.05000',
#   '2. high': '3813.55000',
#   '3. low': '3803.18000',
#   '4. close': '3813.51000',
#   '5. volume': 471},
#  '2021-12-29 02:00:00': {'1. open': '3801.13000',
#   '2. high': '3809.00000',
#   '3. low': '3798.20000',
#   '4. close': '3808.05000',
#   '5. volume': 449},
#  '2021-12-29 01:55:00': {'1. open': '3810.34000',
#   '2. high': '3810.77000',
#   '3. low': '3798.35000',
#   '4. close': '3801.37000',
#   '5. volume': 472},
#  '2021-12-29 01:50:00': {'1. open': '3808.18000',
#   '2. high': '3810.77000',
#   '3. low': '3806.41000',
#   '4. close': '3810.34000',
#   '5. volume': 548},
#  '2021-12-29 01:45:00': {'1. open': '3805.65000',
#   '2. high': '3809.09000',
#   '3. low': '3802.25000',
#   '4. close': '3808.17000',
#   '5. volume': 1021},
#  '2021-12-29 01:40:00': {'1. open': '3799.85000',
#   '2. high': '3807.89000',
#   '3. low': '3799.43000',
#   '4. close': '3805.65000',
#   '5. volume': 940},
#  '2021-12-29 01:35:00': {'1. open': '3801.67000',
#   '2. high': '3806.55000',
#   '3. low': '3797.13000',
#   '4. close': '3800.15000',
#   '5. volume': 462},
#  '2021-12-29 01:30:00': {'1. open': '3810.00000',
#   '2. high': '3810.01000',
#   '3. low': '3795.83000',
#   '4. close': '3801.67000',
#   '5. volume': 1343},
#  '2021-12-29 01:25:00': {'1. open': '3821.95000',
#   '2. high': '3822.07000',
#   '3. low': '3809.98000',
#   '4. close': '3810.00000',
#   '5. volume': 579},
#  '2021-12-29 01:20:00': {'1. open': '3821.26000',
#   '2. high': '3826.24000',
#   '3. low': '3821.26000',
#   '4. close': '3821.95000',
#   '5. volume': 352},
#  '2021-12-29 01:15:00': {'1. open': '3826.01000',
#   '2. high': '3826.01000',
#   '3. low': '3817.32000',
#   '4. close': '3821.53000',
#   '5. volume': 613},
#  '2021-12-29 01:10:00': {'1. open': '3823.30000',
#   '2. high': '3826.07000',
#   '3. low': '3819.00000',
#   '4. close': '3826.00000',
#   '5. volume': 848},
#  '2021-12-29 01:05:00': {'1. open': '3816.91000',
#   '2. high': '3826.85000',
#   '3. low': '3816.91000',
#   '4. close': '3823.30000',
#   '5. volume': 803},
#  '2021-12-29 01:00:00': {'1. open': '3818.06000',
#   '2. high': '3820.41000',
#   '3. low': '3811.57000',
#   '4. close': '3816.91000',
#   '5. volume': 1004},
#  '2021-12-29 00:55:00': {'1. open': '3815.03000',
#   '2. high': '3820.00000',
#   '3. low': '3813.75000',
#   '4. close': '3818.07000',
#   '5. volume': 671},
#  '2021-12-29 00:50:00': {'1. open': '3814.20000',
#   '2. high': '3816.54000',
#   '3. low': '3809.70000',
#   '4. close': '3815.04000',
#   '5. volume': 491},
#  '2021-12-29 00:45:00': {'1. open': '3800.29000',
#   '2. high': '3816.39000',
#   '3. low': '3799.36000',
#   '4. close': '3814.19000',
#   '5. volume': 1036},
#  '2021-12-29 00:40:00': {'1. open': '3795.63000',
#   '2. high': '3800.83000',
#   '3. low': '3792.04000',
#   '4. close': '3800.29000',
#   '5. volume': 656},
#  '2021-12-29 00:35:00': {'1. open': '3802.62000',
#   '2. high': '3804.90000',
#   '3. low': '3792.76000',
#   '4. close': '3795.64000',
#   '5. volume': 889},
#  '2021-12-29 00:30:00': {'1. open': '3809.18000',
#   '2. high': '3809.18000',
#   '3. low': '3795.54000',
#   '4. close': '3802.63000',
#   '5. volume': 707},
#  '2021-12-29 00:25:00': {'1. open': '3812.28000',
#   '2. high': '3813.26000',
#   '3. low': '3806.84000',
#   '4. close': '3809.18000',
#   '5. volume': 569},
#  '2021-12-29 00:20:00': {'1. open': '3817.40000',
#   '2. high': '3819.70000',
#   '3. low': '3811.57000',
#   '4. close': '3812.28000',
#   '5. volume': 472},
#  '2021-12-29 00:15:00': {'1. open': '3818.51000',
#   '2. high': '3820.50000',
#   '3. low': '3810.00000',
#   '4. close': '3817.39000',
#   '5. volume': 960},
#  '2021-12-29 00:10:00': {'1. open': '3809.44000',
#   '2. high': '3821.02000',
#   '3. low': '3806.29000',
#   '4. close': '3818.50000',
#   '5. volume': 782},
#  '2021-12-29 00:05:00': {'1. open': '3785.01000',
#   '2. high': '3810.92000',
#   '3. low': '3785.00000',
#   '4. close': '3809.99000',
#   '5. volume': 1218},
#  '2021-12-29 00:00:00': {'1. open': '3792.75000',
#   '2. high': '3804.17000',
#   '3. low': '3785.00000',
#   '4. close': '3785.00000',
#   '5. volume': 1840},
#  '2021-12-28 23:55:00': {'1. open': '3797.61000',
#   '2. high': '3799.99000',
#   '3. low': '3790.00000',
#   '4. close': '3792.75000',
#   '5. volume': 819},
#  '2021-12-28 23:50:00': {'1. open': '3806.70000',
#   '2. high': '3806.71000',
#   '3. low': '3797.01000',
#   '4. close': '3797.62000',
#   '5. volume': 474},
#  '2021-12-28 23:45:00': {'1. open': '3809.01000',
#   '2. high': '3809.99000',
#   '3. low': '3803.55000',
#   '4. close': '3806.70000',
#   '5. volume': 420},
#  '2021-12-28 23:40:00': {'1. open': '3810.31000',
#   '2. high': '3811.69000',
#   '3. low': '3808.78000',
#   '4. close': '3809.01000',
#   '5. volume': 457},
#  '2021-12-28 23:35:00': {'1. open': '3802.81000',
#   '2. high': '3812.63000',
#   '3. low': '3802.47000',
#   '4. close': '3810.30000',
#   '5. volume': 405},
#  '2021-12-28 23:30:00': {'1. open': '3813.17000',
#   '2. high': '3817.64000',
#   '3. low': '3802.78000',
#   '4. close': '3803.00000',
#   '5. volume': 859},
#  '2021-12-28 23:25:00': {'1. open': '3817.00000',
#   '2. high': '3817.49000',
#   '3. low': '3811.78000',
#   '4. close': '3813.18000',
#   '5. volume': 425},
#  '2021-12-28 23:20:00': {'1. open': '3814.38000',
#   '2. high': '3819.16000',
#   '3. low': '3813.00000',
#   '4. close': '3817.01000',
#   '5. volume': 789},
#  '2021-12-28 23:15:00': {'1. open': '3808.86000',
#   '2. high': '3814.96000',
#   '3. low': '3807.11000',
#   '4. close': '3814.38000',
#   '5. volume': 426},
#  '2021-12-28 23:10:00': {'1. open': '3800.11000',
#   '2. high': '3811.07000',
#   '3. low': '3796.85000',
#   '4. close': '3808.86000',
#   '5. volume': 632},
#  '2021-12-28 23:05:00': {'1. open': '3802.65000',
#   '2. high': '3807.04000',
#   '3. low': '3795.00000',
#   '4. close': '3800.10000',
#   '5. volume': 382},
#  '2021-12-28 23:00:00': {'1. open': '3810.61000',
#   '2. high': '3816.25000',
#   '3. low': '3797.24000',
#   '4. close': '3802.66000',
#   '5. volume': 566},
#  '2021-12-28 22:55:00': {'1. open': '3810.43000',
#   '2. high': '3813.66000',
#   '3. low': '3804.18000',
#   '4. close': '3810.62000',
#   '5. volume': 458},
#  '2021-12-28 22:50:00': {'1. open': '3810.01000',
#   '2. high': '3817.80000',
#   '3. low': '3810.00000',
#   '4. close': '3810.43000',
#   '5. volume': 545},
#  '2021-12-28 22:45:00': {'1. open': '3804.71000',
#   '2. high': '3810.16000',
#   '3. low': '3804.35000',
#   '4. close': '3810.00000',
#   '5. volume': 440},
#  '2021-12-28 22:40:00': {'1. open': '3795.49000',
#   '2. high': '3804.78000',
#   '3. low': '3792.57000',
#   '4. close': '3804.69000',
#   '5. volume': 456},
#  '2021-12-28 22:35:00': {'1. open': '3798.68000',
#   '2. high': '3799.52000',
#   '3. low': '3792.47000',
#   '4. close': '3795.49000',
#   '5. volume': 529},
#  '2021-12-28 22:30:00': {'1. open': '3799.01000',
#   '2. high': '3801.74000',
#   '3. low': '3797.52000',
#   '4. close': '3798.67000',
#   '5. volume': 347},
#  '2021-12-28 22:25:00': {'1. open': '3807.35000',
#   '2. high': '3807.35000',
#   '3. low': '3794.74000',
#   '4. close': '3799.00000',
#   '5. volume': 512},
#  '2021-12-28 22:20:00': {'1. open': '3810.00000',
#   '2. high': '3814.26000',
#   '3. low': '3805.53000',
#   '4. close': '3807.09000',
#   '5. volume': 557},
#  '2021-12-28 22:15:00': {'1. open': '3797.66000',
#   '2. high': '3812.00000',
#   '3. low': '3796.81000',
#   '4. close': '3810.00000',
#   '5. volume': 1014},
#  '2021-12-28 22:10:00': {'1. open': '3813.23000',
#   '2. high': '3814.67000',
#   '3. low': '3792.63000',
#   '4. close': '3797.67000',
#   '5. volume': 1072},
#  '2021-12-28 22:05:00': {'1. open': '3810.52000',
#   '2. high': '3814.06000',
#   '3. low': '3809.92000',
#   '4. close': '3813.22000',
#   '5. volume': 338},
#  '2021-12-28 22:00:00': {'1. open': '3807.03000',
#   '2. high': '3814.01000',
#   '3. low': '3806.76000',
#   '4. close': '3810.52000',
#   '5. volume': 899},
#  '2021-12-28 21:55:00': {'1. open': '3810.55000',
#   '2. high': '3815.26000',
#   '3. low': '3806.27000',
#   '4. close': '3807.03000',
#   '5. volume': 733},
#  '2021-12-28 21:50:00': {'1. open': '3807.45000',
#   '2. high': '3814.72000',
#   '3. low': '3807.28000',
#   '4. close': '3810.54000',
#   '5. volume': 544},
#  '2021-12-28 21:45:00': {'1. open': '3813.17000',
#   '2. high': '3816.42000',
#   '3. low': '3804.09000',
#   '4. close': '3807.18000',
#   '5. volume': 997},
#  '2021-12-28 21:40:00': {'1. open': '3820.49000',
#   '2. high': '3823.91000',
#   '3. low': '3811.13000',
#   '4. close': '3813.17000',
#   '5. volume': 1040},
#  '2021-12-28 21:35:00': {'1. open': '3828.14000',
#   '2. high': '3830.95000',
#   '3. low': '3820.49000',
#   '4. close': '3820.49000',
#   '5. volume': 452},
#  '2021-12-28 21:30:00': {'1. open': '3825.86000',
#   '2. high': '3832.59000',
#   '3. low': '3824.32000',
#   '4. close': '3828.14000',
#   '5. volume': 302},
#  '2021-12-28 21:25:00': {'1. open': '3824.75000',
#   '2. high': '3827.16000',
#   '3. low': '3821.01000',
#   '4. close': '3825.85000',
#   '5. volume': 355},
#  '2021-12-28 21:20:00': {'1. open': '3836.57000',
#   '2. high': '3837.65000',
#   '3. low': '3823.43000',
#   '4. close': '3824.74000',
#   '5. volume': 673},
#  '2021-12-28 21:15:00': {'1. open': '3827.07000',
#   '2. high': '3837.32000',
#   '3. low': '3825.99000',
#   '4. close': '3836.57000',
#   '5. volume': 676},
#  '2021-12-28 21:10:00': {'1. open': '3821.49000',
#   '2. high': '3832.59000',
#   '3. low': '3821.14000',
#   '4. close': '3827.08000',
#   '5. volume': 574},
#  '2021-12-28 21:05:00': {'1. open': '3820.93000',
#   '2. high': '3825.77000',
#   '3. low': '3817.98000',
#   '4. close': '3821.49000',
#   '5. volume': 593},
#  '2021-12-28 21:00:00': {'1. open': '3827.18000',
#   '2. high': '3827.82000',
#   '3. low': '3819.14000',
#   '4. close': '3820.93000',
#   '5. volume': 527},
#  '2021-12-28 20:55:00': {'1. open': '3824.26000',
#   '2. high': '3831.23000',
#   '3. low': '3816.45000',
#   '4. close': '3827.19000',
#   '5. volume': 1436},
#  '2021-12-28 20:50:00': {'1. open': '3836.49000',
#   '2. high': '3836.50000',
#   '3. low': '3818.33000',
#   '4. close': '3824.27000',
#   '5. volume': 1101},
#  '2021-12-28 20:45:00': {'1. open': '3839.01000',
#   '2. high': '3844.44000',
#   '3. low': '3833.42000',
#   '4. close': '3836.50000',
#   '5. volume': 1333},
#  '2021-12-28 20:40:00': {'1. open': '3825.00000',
#   '2. high': '3839.78000',
#   '3. low': '3824.22000',
#   '4. close': '3839.00000',
#   '5. volume': 1127},
#  '2021-12-28 20:35:00': {'1. open': '3820.45000',
#   '2. high': '3826.82000',
#   '3. low': '3819.55000',
#   '4. close': '3824.99000',
#   '5. volume': 813},
#  '2021-12-28 20:30:00': {'1. open': '3817.72000',
#   '2. high': '3821.07000',
#   '3. low': '3814.34000',
#   '4. close': '3820.44000',
#   '5. volume': 506},
#  '2021-12-28 20:25:00': {'1. open': '3818.58000',
#   '2. high': '3820.93000',
#   '3. low': '3815.00000',
#   '4. close': '3817.73000',
#   '5. volume': 428},
#  '2021-12-28 20:20:00': {'1. open': '3819.99000',
#   '2. high': '3821.90000',
#   '3. low': '3815.50000',
#   '4. close': '3818.58000',
#   '5. volume': 1240},
#  '2021-12-28 20:15:00': {'1. open': '3816.57000',
#   '2. high': '3820.00000',
#   '3. low': '3811.67000',
#   '4. close': '3819.99000',
#   '5. volume': 922},
#  '2021-12-28 20:10:00': {'1. open': '3808.99000',
#   '2. high': '3818.03000',
#   '3. low': '3801.58000',
#   '4. close': '3816.57000',
#   '5. volume': 659},
#  '2021-12-28 20:05:00': {'1. open': '3800.52000',
#   '2. high': '3811.45000',
#   '3. low': '3794.82000',
#   '4. close': '3808.98000',
#   '5. volume': 814},
#  '2021-12-28 20:00:00': {'1. open': '3807.96000',
#   '2. high': '3809.93000',
#   '3. low': '3791.23000',
#   '4. close': '3800.52000',
#   '5. volume': 3971},
#  '2021-12-28 19:55:00': {'1. open': '3810.76000',
#   '2. high': '3815.71000',
#   '3. low': '3803.52000',
#   '4. close': '3807.96000',
#   '5. volume': 718},
#  '2021-12-28 19:50:00': {'1. open': '3813.61000',
#   '2. high': '3815.00000',
#   '3. low': '3807.78000',
#   '4. close': '3810.46000',
#   '5. volume': 927},
#  '2021-12-28 19:45:00': {'1. open': '3801.14000',
#   '2. high': '3814.04000',
#   '3. low': '3800.05000',
#   '4. close': '3813.61000',
#   '5. volume': 1137},
#  '2021-12-28 19:40:00': {'1. open': '3792.89000',
#   '2. high': '3806.05000',
#   '3. low': '3792.65000',
#   '4. close': '3801.14000',
#   '5. volume': 783},
#  '2021-12-28 19:35:00': {'1. open': '3791.80000',
#   '2. high': '3796.07000',
#   '3. low': '3785.34000',
#   '4. close': '3792.89000',
#   '5. volume': 922},
#  '2021-12-28 19:30:00': {'1. open': '3784.49000',
#   '2. high': '3796.58000',
#   '3. low': '3781.38000',
#   '4. close': '3791.80000',
#   '5. volume': 897},
#  '2021-12-28 19:25:00': {'1. open': '3791.00000',
#   '2. high': '3793.45000',
#   '3. low': '3782.45000',
#   '4. close': '3784.10000',
#   '5. volume': 718},
#  '2021-12-28 19:20:00': {'1. open': '3772.98000',
#   '2. high': '3791.35000',
#   '3. low': '3770.12000',
#   '4. close': '3791.00000',
#   '5. volume': 908},
#  '2021-12-28 19:15:00': {'1. open': '3772.16000',
#   '2. high': '3785.68000',
#   '3. low': '3771.76000',
#   '4. close': '3772.98000',
#   '5. volume': 1528},
#  '2021-12-28 19:10:00': {'1. open': '3761.36000',
#   '2. high': '3784.66000',
#   '3. low': '3761.36000',
#   '4. close': '3771.75000',
#   '5. volume': 1466},
#  '2021-12-28 19:05:00': {'1. open': '3783.00000',
#   '2. high': '3788.11000',
#   '3. low': '3759.36000',
#   '4. close': '3761.36000',
#   '5. volume': 4207},
#  '2021-12-28 19:00:00': {'1. open': '3800.01000',
#   '2. high': '3800.21000',
#   '3. low': '3781.30000',
#   '4. close': '3783.00000',
#   '5. volume': 1571},
#  '2021-12-28 18:55:00': {'1. open': '3792.71000',
#   '2. high': '3803.18000',
#   '3. low': '3790.52000',
#   '4. close': '3800.02000',
#   '5. volume': 603},
#  '2021-12-28 18:50:00': {'1. open': '3798.68000',
#   '2. high': '3799.31000',
#   '3. low': '3785.00000',
#   '4. close': '3792.71000',
#   '5. volume': 1371},
#  '2021-12-28 18:45:00': {'1. open': '3809.00000',
#   '2. high': '3810.11000',
#   '3. low': '3798.06000',
#   '4. close': '3798.43000',
#   '5. volume': 832},
#  '2021-12-28 18:40:00': {'1. open': '3805.93000',
#   '2. high': '3814.52000',
#   '3. low': '3805.92000',
#   '4. close': '3809.01000',
#   '5. volume': 672},
#  '2021-12-28 18:35:00': {'1. open': '3812.44000',
#   '2. high': '3815.64000',
#   '3. low': '3803.32000',
#   '4. close': '3805.92000',
#   '5. volume': 634},
#  '2021-12-28 18:30:00': {'1. open': '3803.11000',
#   '2. high': '3814.37000',
#   '3. low': '3800.55000',
#   '4. close': '3812.45000',
#   '5. volume': 992},
#  '2021-12-28 18:25:00': {'1. open': '3791.63000',
#   '2. high': '3803.90000',
#   '3. low': '3791.62000',
#   '4. close': '3803.12000',
#   '5. volume': 933},
#  '2021-12-28 18:20:00': {'1. open': '3803.45000',
#   '2. high': '3806.11000',
#   '3. low': '3790.02000',
#   '4. close': '3791.63000',
#   '5. volume': 940}}

# %% [markdown]
# ## Cryptowatch

# %%
cw_key='c8dddf9e-ac93-46bb-93cd-bc3d19b04a4f'

# %%
from requests import Request, Session
from requests.exceptions import ConnectionError, Timeout, TooManyRedirects
import json

url = 'https://pro-api.coinmarketcap.com/v1/cryptocurrency/listings/latest'
parameters = {
  'start':'1',
  'limit':'5000',
  'convert':'USD'}

headers = {
  'Accepts': 'application/json',
  'X-CMC_PRO_API_KEY': cw_key,}

session = Session()
session.headers.update(headers)

try:
    response = session.get(url, params=parameters)
    data = json.loads(response.text)
except (ConnectionError, Timeout, TooManyRedirects) as e:
    print(e)

# %%
print(data['data'][0]['symbol'])
# Out:
# BTC

# %%
data['data'][0]['quote']
# Out:
# {'USD': {'price': 56799.76951166105,
#   'volume_24h': 34617907498.34209,
#   'volume_change_24h': 20.7863,
#   'percent_change_1h': -0.12141074,
#   'percent_change_24h': -0.24645822,
#   'percent_change_7d': -7.0671565,
#   'percent_change_30d': -6.89184884,
#   'percent_change_60d': 28.3517913,
#   'percent_change_90d': 17.97393378,
#   'market_cap': 1072423668201.5321,
#   'market_cap_dominance': 41.8394,
#   'fully_diluted_market_cap': 1192795159744.88,
#   'last_updated': '2021-11-23T05:12:02.000Z'}}

# %%
len(data['data'])
# Out:
# 5000

# %%
import cryptowatch as cw
from datetime import datetime, timedelta

# %%
# Get all Kraken markets
kraken = cw.markets.list("kraken")

# For each Kraken market...
for market in kraken.markets:

    # Forge current market ticker, like KRAKEN:BTCUSD
    ticker = "{}:{}".format(market.exchange, market.pair).upper()
    # Request weekly candles for that market
    candles = cw.markets.get(ticker, ohlc=True, periods=["1w"])

    # Each candle is a list of [close_timestamp, open, high, low, close, volume, volume_quote]
    # Get close_timestamp, open and close from the most recent weekly candle
    close_ts, wkly_open, wkly_close = (
        candles.of_1w[-1][0],
        candles.of_1w[-1][1],
        candles.of_1w[-1][4],
    )

    # Compute market performance, skip if open was 0
    if wkly_open == 0:
        continue
    perf = (wkly_open - wkly_close) * 100 / wkly_open

    # If the market performance was 5% or more, print it
    if perf >= 5:
        open_ts = datetime.utcfromtimestamp(close_ts) - timedelta(days=7)
        print("{} gained {:.2f}% since {}".format(ticker, perf, open_ts))
# Out:
# KRAKEN:BTCEUR gained 13.84% since 2021-12-02 00:00:00
# KRAKEN:BTCUSD gained 14.06% since 2021-12-02 00:00:00
# KRAKEN:BTCGBP gained 13.36% since 2021-12-02 00:00:00
# KRAKEN:BTCJPY gained 14.16% since 2021-12-02 00:00:00
# KRAKEN:BTCCAD gained 13.14% since 2021-12-02 00:00:00
# KRAKEN:LTCEUR gained 20.69% since 2021-12-02 00:00:00
# KRAKEN:LTCBTC gained 7.95% since 2021-12-02 00:00:00
# KRAKEN:LTCUSD gained 20.92% since 2021-12-02 00:00:00
# KRAKEN:ETHUSD gained 10.61% since 2021-12-02 00:00:00
# KRAKEN:ETHEUR gained 10.33% since 2021-12-02 00:00:00
# KRAKEN:ETHCAD gained 9.95% since 2021-12-02 00:00:00
# KRAKEN:ETHGBP gained 9.99% since 2021-12-02 00:00:00
# KRAKEN:ETHJPY gained 10.38% since 2021-12-02 00:00:00
# KRAKEN:ETCETH gained 8.32% since 2021-12-02 00:00:00
# KRAKEN:ETCUSD gained 17.38% since 2021-12-02 00:00:00
# KRAKEN:ETCEUR gained 16.83% since 2021-12-02 00:00:00
# KRAKEN:GNOUSD gained 8.32% since 2021-12-02 00:00:00
# KRAKEN:GNOEUR gained 8.22% since 2021-12-02 00:00:00
# KRAKEN:EOSETH gained 10.88% since 2021-12-02 00:00:00
# KRAKEN:EOSBTC gained 8.31% since 2021-12-02 00:00:00
# KRAKEN:EOSEUR gained 20.98% since 2021-12-02 00:00:00
# KRAKEN:EOSUSD gained 21.20% since 2021-12-02 00:00:00
# KRAKEN:REPETH gained 8.32% since 2021-12-02 00:00:00
# KRAKEN:REPEUR gained 17.11% since 2021-12-02 00:00:00
# KRAKEN:REPUSD gained 17.26% since 2021-12-02 00:00:00
# KRAKEN:ZECCAD gained 16.63% since 2016-12-15 00:00:00
# KRAKEN:ZECEUR gained 17.40% since 2021-12-02 00:00:00
# KRAKEN:ZECGBP gained 18.54% since 2016-12-15 00:00:00
# KRAKEN:ZECUSD gained 18.03% since 2021-12-02 00:00:00
# KRAKEN:XMREUR gained 11.81% since 2021-12-02 00:00:00
# KRAKEN:XMRUSD gained 12.30% since 2021-12-02 00:00:00
# KRAKEN:XLMEUR gained 10.90% since 2021-12-02 00:00:00
# KRAKEN:XLMUSD gained 11.12% since 2021-12-02 00:00:00
# KRAKEN:XRPUSD gained 14.45% since 2021-12-02 00:00:00
# KRAKEN:XRPEUR gained 14.20% since 2021-12-02 00:00:00
# KRAKEN:XRPCAD gained 14.16% since 2021-12-02 00:00:00
# KRAKEN:XRPJPY gained 14.61% since 2021-12-02 00:00:00
# KRAKEN:DASHBTC gained 7.05% since 2021-12-02 00:00:00
# KRAKEN:DASHEUR gained 19.67% since 2021-12-02 00:00:00
# KRAKEN:DASHUSD gained 19.62% since 2021-12-02 00:00:00
# KRAKEN:FLOWEUR gained 18.83% since 2021-12-02 00:00:00
# KRAKEN:FLOWGBP gained 17.75% since 2021-12-02 00:00:00
# KRAKEN:FLOWUSD gained 18.88% since 2021-12-02 00:00:00
# KRAKEN:FLOWBTC gained 5.49% since 2021-12-02 00:00:00
# KRAKEN:FLOWETH gained 9.36% since 2021-12-02 00:00:00
# KRAKEN:OCEANEUR gained 16.96% since 2021-12-02 00:00:00
# KRAKEN:OCEANGBP gained 15.53% since 2021-12-02 00:00:00
# KRAKEN:OCEANUSD gained 16.63% since 2021-12-02 00:00:00
# KRAKEN:DOGEUSDT gained 14.74% since 2021-12-02 00:00:00
# KRAKEN:ZRXBTC gained 9.42% since 2021-12-02 00:00:00
# KRAKEN:RENGBP gained 20.22% since 2021-12-02 00:00:00
# KRAKEN:ZRXGBP gained 19.95% since 2021-12-02 00:00:00
# KRAKEN:MKRGBP gained 12.43% since 2021-12-02 00:00:00
# KRAKEN:RENEUR gained 21.22% since 2021-12-02 00:00:00
# KRAKEN:ZRXUSD gained 22.24% since 2021-12-02 00:00:00
# KRAKEN:MKRUSD gained 12.92% since 2021-12-02 00:00:00
# KRAKEN:RENBTC gained 8.35% since 2021-12-02 00:00:00
# KRAKEN:ZRXEUR gained 21.92% since 2021-12-02 00:00:00
# KRAKEN:MKREUR gained 12.20% since 2021-12-02 00:00:00
# KRAKEN:RENUSD gained 21.27% since 2021-12-02 00:00:00
# KRAKEN:RARIEUR gained 9.99% since 2021-12-02 00:00:00
# KRAKEN:GHSTUSD gained 11.34% since 2021-12-02 00:00:00
# KRAKEN:RARIGBP gained 7.12% since 2021-12-02 00:00:00
# ---------------------------------------------------------------------------
# HTTPError                                 Traceback (most recent call last)
# ~/opt/anaconda3/lib/python3.8/site-packages/cryptowatch/requestor.py in get_resource(self, resource)
#      88             )
# ---> 89             resp.raise_for_status()
#      90         # Only catch API Errors, let other Exceptions bubble up
#
# ~/opt/anaconda3/lib/python3.8/site-packages/requests/models.py in raise_for_status(self)
#     942         if http_error_msg:
# --> 943             raise HTTPError(http_error_msg, response=self)
#     944
#
# HTTPError: 429 Client Error: Too Many Requests for url: https://api.cryptowat.ch/markets/kraken/maticusd/ohlc?periods=604800
#
# During handling of the above exception, another exception occurred:
#
# APIRateLimitError                         Traceback (most recent call last)
# <ipython-input-3-b432f22c0330> in <module>
#       8     ticker = "{}:{}".format(market.exchange, market.pair).upper()
#       9     # Request weekly candles for that market
# ---> 10     candles = cw.markets.get(ticker, ohlc=True, periods=["1w"])
#      11
#      12     # Each candle is a list of [close_timestamp, open, high, low, close, volume, volume_quote]
#
# ~/opt/anaconda3/lib/python3.8/site-packages/cryptowatch/resources/markets.py in get(self, market, liquidity, orderbook, trades, ohlc, periods)
#      44             resource = "/markets/{}/{}/summary".format(exchange, pair)
#      45             schema = MarketSummaryAPIResponseSchema()
# ---> 46         data, http_resp = self.client.get_resource(resource)
#      47         market_resp = json.loads(data)
#      48         market_obj = schema.load(market_resp)
#
# ~/opt/anaconda3/lib/python3.8/site-packages/cryptowatch/requestor.py in get_resource(self, resource)
#     103                     "Upgrade for a higher allowance at https://cryptowat.ch/pricing",
#     104                 )
# --> 105                 raise cryptowatch.errors.APIRateLimitError(
#     106                     msg, resp.text, resp.status_code, resp.request.headers,
#     107                 )
#
# APIRateLimitError: For unlimited API access, create an account at https://cryptowat.ch
